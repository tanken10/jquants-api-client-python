# %% [markdown]
# # リフレッシュトークンの書き込み
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/J-Quants/jquants-api-client-python/blob/master/examples/20220825-000-write-refresh_token.ipynb)
#
# J-Quants API のリフレッシュトークンを Google Drive の MyDrive/drive_ws/secret/jquantsapi-key.txt に書き込みます。
#
# リフレッシュトークンは取得方法は以下のリンク先をご参照ください。
#
# https://jpx.gitbook.io/j-quants-api/api-reference#idtkunno
#
#
# ----
#
# **このノートブックはGoogle Driveを使用します。**
#
# - Google Drive の以下のファイルにリフレッシュトークンを書き込みます。
#     - `MyDrive/drive_ws/secret/jquantsapi-key.txt`

# %%
# # Google drive をマウントします
# from google.colab import drive
# drive.mount('/content/drive')

# 必要なモジュールを読み込みます
import os
from getpass import getpass


# refresh_token を入力します
refresh_token = getpass("Please input refresh token")
# refresh_token が変わった時に入力簡易化できるように
# refresh_token = getpass("")
# refresh_token = getpass("eyJjdHkiOiJKV1QiLCJlbmMiOiJBMjU2R0NNIiwiYWxnIjoiUlNBLU9BRVAifQ.m0R8wtBjw9tLF2twyIkVI9sZY1Pa6M8DgRFXJUYECaH_rZLDY35uuor3ISZq0YAXmngnaYzXtf-R6qmacwTiFeF9BJQZdF-w2GZI0ovvqNGVcSBiiuQ_JzuJmeZwM1qTTUJW3dluGaUk-S5O60VAXV7mLMnzKpBEhmsnEinmjJxttHsXBNAxk1E9DmCIlusLQg-VATvG9Oiyv0mk0_4jF_MsaJ93aKLkCLzyhS5VaDV7s8T6-0-0XNAHsN1LBpr5ZxEQLzPL_GL0b32VWKE2ngCpUP6YazFK02anOKBD96lAgnuFGVwsvQAOvL5GmStUDHXuKPBiC6Onee7HrE-X8g.V3gsImVE_otfF25C.Rt2lDikCEr58aLOfMH6lfJWCYdM3IHvLiYEjnjvTMgLdDD41i6Y_jN8KouAahuEd2QLHb_HEyNDoc3bdN5e8HVYuJLxMlmrdUuWL3a2MQWybO73zBOhSC6CNh2PuJJqzsv6R9d_CfzPVp_IcYJzJdeR2_cdCmjCIHQY_nGBvtd__FSmYYY0rmGiiN_nxoR-X9EUShl9K7yp-qRS5JPPk-wRwfskYWQJdcRXT_fHgSJHhDWIAeJ6-cFsqgTyejUfHdcjsdz2PM5-c0s_iiv53rCmLSdJSY29zrSKQE06Np9Fq_KEOUZHjtnbudYj43UYX1quGBJxw742UtZbMzbAWGNRSLWc7tWVSPe5tBy-XN5n70q2JmTl5_63dQD-nuU0rs_-2FgOr9h8WK6HoCE6hxJ-hDhXnZElbSNHjQUI9rQkVS2XQS7uH8ei-1y8TjFzVIB8zXtQhbtReNgvaimTYUeXCGLYn7rJS2Luyp8MGrqeuZrLPI3VXVypqp_wHGUKhHVJK7Xyh5vnHEJ53swyYY0VN8lAf0wiJu034kqvFokgZ8ocX7uxzrKnzPgmz2cLBox5kCz6TC9bnC_wnuDKVbJESIeEmf9ILrzgBCogl2u14CTXLmcKTHLmcp-KDHL-AyZF9uvD1L20EfM4xknPlUsm4ckLfTin99oZicw5khceiqBOgzXCRuHBJmTlvWMP1kydP7GM3Ml1SvNSO6xvP_ep1k2brfjmQ5t70lth03xNWc3rRO2UFyBHR2aa5Da-cmGzjugRLsnb-n-akaqZHx29K3m2_Ufg5EIIm9WzQ_9yPHH9bAbeQE7u6awbcPcNha6n78dVfC50wRAMo2I47-uXK_WdRhXrYeuxn9QoufLUBcQnEmOgLZIU7s6jh4Qu7fHR6Y0Ys91GWppQqtTFreW25K-0bpMmUHnv6iJGZWy4SNpsCUT18xdSTVrcQ_Mf0mhbMllgJVD3nHvoBxPUX6E31wvJjKzPq5XupkBTV41s6ijkn6tE4b4Voe3kUswwCC4d1fOHs8QocE29jh0IconMVBzidbVZAqkwzC2AvCs3hwu9mDl7fHgKLD4VPTPBYIcqaQLX9dWy83aRMLi5meurQvl_Mh-8fnx3_EsAL9uMBFb8zsdGL2Nm4Ab4epAhRtJJ2oC5XsZemEEEk2wEXLWXRdvyrpkFFhWotnA-7-fS1fvXaBmM0jirGVUen_bUipqTJFFlVBMbv3AQrt83xCmN6lB_YPV3uHMHLphjC0g-4M32cL2pUyfIxPLTcXeYnoeAjd6sI81aiUlEZfElymvaPljpLmIrB3ByT9kVhYFVNn9M9c0rsfso873J1M-xfiaxQRjB0diPvmA.zKzckKFSRnmCARP0egffPw")

# refresh_token の書き込み先を指定します
OUTPUT_DIR = "../drive_ws/secret"
OUTPUT_PATH = f"{OUTPUT_DIR}/jquantsapi-key.txt"
print(OUTPUT_PATH)

# refresh_token を書き込みます
os.makedirs(OUTPUT_DIR, exist_ok=True)
with open(OUTPUT_PATH, mode="w") as f:
  f.write(refresh_token)

# 完了文字列を表示します
print("Done")
# Out:
# ../drive_ws/secret/jquantsapi-key.txt
# Done
