# %% [markdown]
# # リフレッシュトークンの書き込み
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/J-Quants/jquants-api-client-python/blob/master/examples/20220825-000-write-refresh_token.ipynb)
#
# J-Quants API のリフレッシュトークンを Google Drive の MyDrive/drive_ws/secret/jquantsapi-key.txt に書き込みます。
#
# リフレッシュトークンは取得方法は以下のリンク先をご参照ください。
#
# https://jpx.gitbook.io/j-quants-api/api-reference#idtkunno
#
#
# ----
#
# **このノートブックはGoogle Driveを使用します。**
#
# - Google Drive の以下のファイルにリフレッシュトークンを書き込みます。
#     - `MyDrive/drive_ws/secret/jquantsapi-key.txt`

# %%
# # Google drive をマウントします
# from google.colab import drive
# drive.mount('/content/drive')

# 必要なモジュールを読み込みます
import os
from getpass import getpass


# refresh_token を入力します
refresh_token = getpass("eyJjdHkiOiJKV1QiLCJlbmMiOiJBMjU2R0NNIiwiYWxnIjoiUlNBLU9BRVAifQ.DivR2SI-kSkdtU_PKhbvtoSjm2f41z8K10gynxX77LCZE2EfjAn8yiybY10AengdVJLaoXSP8-vP_EIiGDW4G03RVXR-06xFtUhOaXMU1WQR0A0u1XK8bFJbYxWQ9lxGZ5u7ppV7fJC4QeiK-DTATTke7DCbYXeZPtcifYYpROP_LQrcLohRue6w5BmN7ZKXw1Tw__UGL1qFF14RwEEIN11hldQjS3NN1_wKW7RgVPQ2T1Hvv79G2BS18w4wfKBik2En8APOPvggjY_zejmxVabrj1bnnksBhF-iiuZO85Kf4U3qrm6dnrhq31PbbX4KQPEBdK5BquCWZLf6V_EjRA.DXromL-Hqddxjgij.QamKdpehoMm6Z0ROUdfTXOFPc5X0bGxlBvRAipWCsyL94AYuz_jZkAOfNTNZp6zpPkC2RrYCfKpAuaUAt8wLIvcJflNiYQYyQWrfPAx3z8CK90pCHheKYAjGdJkb51aL0XAol9Sku9iDpl6CVh24cJYk8St57FkKfeJUIboRpK4zAQO1n6euxYirUKnkyCD0_3O8px3Ep4otcIxVpKQ_5_MOfjNTar6-oB-5Iv8yfHzyIZctJStBwL9c2Nh2TYhTXnJkbGEP8QhptvZiuTHTuTRJwW2PNkkjmLpMPfpLxmc1ouFUg5YXk9BxzrnuzaBfZ7QK0PqtJsqBRlv5Xlk0qAKx68wbFQ4mVyVBdKI2FTz30p_KZRA66JSIN1Sje2PnOqWa8NRsANJANZu5qbiVu9iw6Iv5eS7aOrSHFzzJmVqZ4jonzExQr5D-2NZxsZtS3YliqH23gs7XA2YbEzxQOUwDvn6J4L4_Xa8UAUZHjlTNqhAtvkyJur09wdhvIdk6AK6-H4o0DBItyBADHiDdKEGybWAcP_2LoehMCE4sdj6l0_MSW1PVjasgVNK3-1IFG2APFIvA4g3S_Cns5oPvaJ20ExIatZXzuid1A-xnn6J7ewAtu2u4M-yUuIctBB87DKrQAez9eoT9gvo3krdu6yrViFtodxV37S1bmGwRu0m6Iy5Yo-cLWzRkCZCGGyaeRo2EhSwtM2dF1Kjnco1aIJfFlO2rkNSJNbt3photsmY3o7OuqASk0KAz1ySUWIkJhfejflfPM-qRnB-2nnp7_QW7wK3u_R35Uvq4VonNf9OwMbVPUPZtTa_3m_esmOKYLg7kDPhVazHwOOCUNBHR3bUf9nyKZf928l_wjkbRHf0oRnKrsUi5WAj7VUbpVcPMsYCG4FawzcqnVqJLSj4I_ptc4wY-bnwVfMCrjdno21l8MNge8rulR3FrRIfIQ3x7DbX6NiF1caj0Ywbf08Lmv-yVO2HVCwwLkZi1LDYftTawLysRBpx3LqNpuqVpui28RQG2S_OD5nkM_w0h5PNVqBLGAkN-zPjIDcRyk8k3vKWTiM5nEZ5g59n67N-3WqzSYfx4RPykPRb-N_OY0J46XH_PdKWRQ0kCY_u8pnZ0lHtJCRoteH0bUhEO5LZYLC1xU2LV5HXbr5iX3zcDfWXuK6SpEwIjo5Iy20_br__Eyz41vJj3Tym-vBDLwTe-M7JhZ4CqGlT_kY_aBgwkd3po6IKoJnYzRNwPYjRzNZN4lDLTh-dIT6XqR58RR98RdQX3Dy3anVzX-0Nw9Ggze2Ff_nD7pFKS243wI94tiauWS6PWrJ4ZsmZRr-n0uCnef3z-lthMkJttWuW8jQ.V36rZt1yEzD4XrMV6zLvrQ")

# refresh_token の書き込み先を指定します
OUTPUT_DIR = "../drive_ws/secret"
OUTPUT_PATH = f"{OUTPUT_DIR}/jquantsapi-key.txt"

# refresh_token を書き込みます
os.makedirs(OUTPUT_DIR, exist_ok=True)
with open(OUTPUT_PATH, mode="w") as f:
  f.write(refresh_token)

# 完了文字列を表示します
print("Done")
# Out:
# Done
